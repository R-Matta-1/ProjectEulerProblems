# %% [markdown]
# A unit fraction contains $1$ in the numerator. The decimal representation of the unit fractions with denominators $2$ to $10$ are given:
# \begin{align}
# 1/2 = 0.5\\
# 1/3 =0.(3)\\
# 1/4 =0.25\\
# 1/5 = 0.2\\
# 1/6 = 0.1(6)\\
# 1/7 = 0.(142857)\\
# 1/8 = 0.125\\
# 1/9 = 0.(1)\\
# 1/10 = 0.1
# \end{align}
# Where $0.1(6)$ means $0.166666\cdots$, and has a $1$-digit recurring cycle. It can be seen that $1/7$ has a $6$-digit recurring cycle.
# Find the value of $d \lt 1000$ for which $1/d$ contains the longest recurring cycle in its decimal fraction part.

# %% [markdown]
# STEP one, get some more acuracy
# ---
# ---

# %%
from decimal import Decimal, getcontext

# Set the precision to a higher value
getcontext().prec = 50

def DetailedReciprocal(n: int) -> str:
    return str(Decimal(1) / Decimal(n))[2::]

print(DetailedReciprocal(7))
# Out:
# 14285714285714285714285714285714285714285714285714

# %% [markdown]
# Step 2, locate patterns
# ---
# ---

# %%
def LargestCycle(n: str) -> int:
    # todo: this
    return 0

for i in range(1, 100):
    string = DetailedReciprocal(i)
    print(i,"\t",len(string),"\t",string)
# Out:
# 1 	 0
# 2 	 1 	 5
# 3 	 50 	 33333333333333333333333333333333333333333333333333
# 4 	 2 	 25
# 5 	 1 	 2
# 6 	 50 	 16666666666666666666666666666666666666666666666667
# 7 	 50 	 14285714285714285714285714285714285714285714285714
# 8 	 3 	 125
# 9 	 50 	 11111111111111111111111111111111111111111111111111
# 10 	 1 	 1
# 11 	 51 	 090909090909090909090909090909090909090909090909091
# 12 	 51 	 083333333333333333333333333333333333333333333333333
# 13 	 51 	 076923076923076923076923076923076923076923076923077
# 14 	 51 	 071428571428571428571428571428571428571428571428571
# 15 	 51 	 066666666666666666666666666666666666666666666666667
# 16 	 4 	 0625
# 17 	 51 	 058823529411764705882352941176470588235294117647059
# 18 	 51 	 055555555555555555555555555555555555555555555555556
# 19 	 51 	 052631578947368421052631578947368421052631578947368
# 20 	 2 	 05
# 21 	 51 	 047619047619047619047619047619047619047619047619048
# 22 	 51 	 045454545454545454545454545454545454545454545454545
# ...
